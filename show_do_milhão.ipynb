# %%
import random

facil=["1;Oque é uma banana?;Tuberculo;Legume;Pseudofruto;Fruta;D",
       "1;Quanto é 35+75?;100;105;90;110;D",
       "1;Qual é o coletivo de cães?;Matilha;Rebanho;Alcateia;Manada;A",
       "1;Que fruta é ressecada para se tornar uma ameixa seca?;Ameixa;Uva;Melão;Amora;A",
       "1;Quantas folhas tem um trevo da sorte?;Tres;Quatro;Cinco;Duas;B",
       "1;Um século tem quantos anos?;50;1000;100;1500;C",
       "1;Qual a profissão dos Sete Anões no conto Bela adormecida?;Agricultores;Padeiros;Mineiros;Guerreiros;C",
       "1;Qual marca de artigos espotivos tem um felino como simbolo;Adidas;Nike;Puma;Asics;C",
       "1;Qual das opições é uma fonte de energia renovável;Eolica;Petroleo;Carvão;Gás;A",
       "1;Qual a capital do Brasil?;Bahia;Rio de Janeiro;São Paulo;Brasília;D"]

medio=["2;Seguindo a sequência do baralho, qual carta vem depois do dez?;Ás;Valete;Dez;Rainha;B",
       "2;O adjetivo venoso está relacionado a:;Veia;Vela;Vento;Veneno;A",
       "2;Em que país fica o Taj Mahal?;Indonésia;India;Russia;Turquia;B",
       "2;Na mitologia grega como se chama a deusa da sabedoría?;Asthefone;Atena;Diana;Artemis;B",
       "2;Segundo a declaração de 1959 da ONU, qual da hipoteses é um direito universal de todas as crianças?;Jogos;Educação;Acesso a internet;Salario minimo;B",
       "2;Qual a capital da Roménia?;Roterdão;Atenas;Roma;Bucareste;D",
       "2;Qual monumento é famoso por estar inclinado?;Torre Eiffel;Torre de Cantão;Torre de pizza;Farol de Alexandria;C",
       "2;Miró, Picasso e Salvador Dalí eram pintores:;Espanhóis;Portugueses;Italianos;Ingleses;A",
       "2;Como são chamados os clarões de descargas elétricas observados em um dia de temporal?;Relâmpago;Trovoada;Estrondo;Trovão;A",
       "2;Bosque é o coletivo de:;Arvores;Folhas;Pedras;Animais;A"]

dificil=["3;Quem foi o último presidente brasileiro da era militar?;Medici;Figueiredo;Geisel;Sarney;B",
         "3;Qual é maior dos nossos érgãos sensoriais?;A pele;A visão;A audição;O oufato;A",
         "3;Até 1997, Hong Kong era adiministrada por qual país?;Fraça;Estados Unidos;China;inglaterra;D",
         "3;Em qual alternativa só há ditongo oral?;Noite,Pão,Paes;Pão,Paes,Efeito;Cai,Visões,Efeito;Cai,Mau,Efeito;D",
         "3;Em que ano ocorreu a revolta da Chibata?;1920;1910;1918;1908;C",
         "3;Em inglês oque não é uma sobremesa?;Monday;Cake;Sunday;Pie;A",
         "3;Quem escreveu a história Hansel e Gretel?;Edgar Allan Poe;Johann Wolfgang;Os irmãos Grimm;JK Rowling;C",
         "3;Qual o nome do sindicato que Lech Walesa fundou na Polônia em 1980?;Comunista;Trabalhista;Conservador;Solidariedade;D",
         "3;Que famoso filme tem como cenário principal o Coliseu de Roma?;O gladiador;300;A Legião Perdida;Centurião;A",
         "3;Quantos 9 existem entre 0 a 100?;9;10;11;8;C"]

hardcore=["4;Quem foi a única pessoa na história a receber o Prêmio Nobel em áreas científicas diferentes?;Linus Pauling;Marie Curie;Albert Einstein;;Stephen Hawking;B",
          "4;No romance Dom Casmurro, de Machado de Assis, qual o nome do amigo que Bentinho imagina ser o pai de seu filho?;Scolari;Espinosa;Escobar;Estevão;C",
          "4; Quais planetas do sistema solar realizam seu movimento de rotação em sentido horário?;Vênus e Urano;Saturno e Júpiter;Mercúrio e Saturno;Vênus e Netuno;A"]

lista_repostas_possiveis = ['a','A','b','B','c','C','d','D'] #evitar que digitem errado(fora das escolhas)

random.shuffle(facil)
random.shuffle(medio)
random.shuffle(dificil)

len(facil[0:3])
len(medio[0:3])
len(dificil[0:3])


with open("questoes.txt","w") as arq_quest:
  for indice, quest in enumerate(facil):
    arq_quest.write(quest)
    arq_quest.write("\n")
  for indice, quest in enumerate(medio):
    arq_quest.write(quest)
    arq_quest.write("\n")
  for indice, quest in enumerate(dificil):
    arq_quest.write(quest)
    arq_quest.write("\n")
  for indice, quest in enumerate(hardcore):
    arq_quest.write(quest)
    arq_quest.write("\n")

print(" \n#--------------------------#\n|                          |  \n|      JOGO DO MILHÃO      |  \n|                          |  \n|   Conhecimentos gerais   |  \n|                          |  \n#--------------------------#\n")



def jogo():

  #teste de variaveis
  pontos = 0
  dificuldade = "1"

  with open("questoes.txt", "r") as arq_questoes:
     for linha in arq_questoes:
        dados = linha.strip().split(';')
        #dificuldade = dados[0]

        if pontos < 25000:
          dificuldade = "1"
          if dificuldade == dados[0]:
            questoes = dados[1]  # Índice 1 contém a questão
            resposta_a = dados[2]  # Índice 2 contém a resposta A
            resposta_b = dados[3]  # Índice 3 contém a resposta B
            resposta_c = dados[4]  # Índice 4 contém a resposta C
            resposta_d = dados[5]  # Índice 5 contém a resposta D
            resposta_correta = dados[6]  # Índice 6 contém a resposta correta

            print(" \n#---------------------#\n|                     |  \n| Valendo 5 mil reais |  \n|                     |  \n#---------------------#\n")

            print("\n|Questão:", questoes)
            print("|A) ", resposta_a)
            print("|B) ", resposta_b)
            print("|C) ", resposta_c)
            print("|D) ", resposta_d)


            resposta_usuario = input("\nDigite a resposta correta (A, B, C ou D): ")
            if resposta_usuario.upper() == resposta_correta.upper():
              print("\n!Resposta correta, você ganhou mais 5 mil reais!")
              pontos += 5000

            else:
              print("\nQue pena, resposta incorreta!")
              print("\nVocê acumulou: RS", pontos,"reais")
              break


        elif pontos >=25000 and pontos <75000:
          dificuldade = "2"
          if dificuldade == dados[0]:
              questoes = dados[1]
              resposta_a = dados[2]
              resposta_b = dados[3]
              resposta_c = dados[4]
              resposta_d = dados[5]
              resposta_correta = dados[6]

              print(" \n#---------------------#\n|                     |  \n| Valendo 10 mil reais |  \n|                     |  \n#---------------------#\n")

              print("\n|Questão:", questoes)
              print("|A) ", resposta_a)
              print("|B) ", resposta_b)
              print("|C) ", resposta_c)
              print("|D) ", resposta_d)



              resposta_usuario = input("\nDigite a resposta correta (A, B, C ou D): ")
              if resposta_usuario.upper() == resposta_correta.upper():
                print("\n!Resposta correta, você ganhou mais 10 mil reais!")
                pontos += 10000

              else:
                print("\nQue pena, resposta incorreta!")
                print("\nVocê acumulou: RS", pontos,"reais")
                break


        elif dados[0] == '3':
            questoes = dados[1]
            resposta_a = dados[2]
            resposta_b = dados[3]
            resposta_c = dados[4]
            resposta_d = dados[5]
            resposta_correta = dados[6]

            print(" \n#---------------------#\n|                     |  \n| Valendo 50 mil reais | \n|                     |  \n#---------------------#\n")

            print("\n|Questão:", questoes)
            print("|A) ", resposta_a)
            print("|B) ", resposta_b)
            print("|C) ", resposta_c)
            print("|D) ", resposta_d)



            resposta_usuario = input("\nDigite a resposta correta (A, B, C ou D): ")
            if resposta_usuario.upper() == resposta_correta.upper():
                print("\n!Resposta correta, você ganhou mais 50 mil reais!")
                pontos += 50000

            else:
                print("\nQue pena, resposta incorreta!")
                print("\nVocê acumulou: RS", pontos,"reais")
                break

            return pontos


jogo()
# Out:
#
# #--------------------------#
# |                          |
# |      JOGO DO MILHÃO      |
# |                          |
# |   Conhecimentos gerais   |
# |                          |
# #--------------------------#
#
#
# #---------------------#
# |                     |
# | Valendo 5 mil reais |
# |                     |
# #---------------------#
#
#
# |Questão: Quantas folhas tem um trevo da sorte?
# |A)  Tres
# |B)  Quatro
# |C)  Cinco
# |D)  Duas
#
# Digite a resposta correta (A, B, C ou D): b
#
# !Resposta correta, você ganhou mais 5 mil reais!
#
# #---------------------#
# |                     |
# | Valendo 5 mil reais |
# |                     |
# #---------------------#
#
#
# |Questão: Qual marca de artigos espotivos tem um felino como simbolo
# |A)  Adidas
# |B)  Nike
# |C)  Puma
# |D)  Asics
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
